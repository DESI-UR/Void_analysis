# %% [markdown]
# Calculate the Bayes Factor for $g-r$ to determine whether the void and wall samples are drawn from the same or different parent distributions.

# %%
from astropy.table import Table
from astropy.io import fits

import numpy as np

import sys

import pickle

import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc

import matplotlib
import matplotlib.pyplot as plt

from functions import Model_1_plot, Model_2_plot, uniform, jeffreys, Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler
#from functions_gauss import Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler

np.set_printoptions(threshold=sys.maxsize)

# %%
matplotlib.rc('font', size=14)
matplotlib.rc('font', family='DejaVu Sans')

# %% [markdown]
# # Data

# %%
# data_directory = '../../../../data/'
data_directory = '../../../../Data/NSA/'
data_filename = data_directory + 'NSA_v1_0_1_VAGC_vflag-V2-VF.fits'

hdu = fits.open(data_filename)
data = Table(hdu[1].data)
hdu.close()

# %% [markdown]
# ## Just keep the main SDSS DR7 footprint

# %%
# When the catalog is the NSA, only keep those objects which were originally in the DR7 LSS
catalog_SDSS = data[data['IN_DR7_LSS'] == 1]

ra_boolean = np.logical_and(catalog_SDSS['RA'] > 110, catalog_SDSS['RA'] < 270)
catalog_north = catalog_SDSS[ra_boolean]

strip_boolean = np.logical_and.reduce([catalog_north['RA'] > 250, 
                                       catalog_north['RA'] < 269, 
                                       catalog_north['DEC'] > 51, 
                                       catalog_north['DEC'] < 67])
catalog_main = catalog_north[~strip_boolean]

# %%
gr_NSA = np.array(catalog_main['g_r'])

# %%
len(gr_NSA)
# Out:
# 514587

# %% [markdown]
# ## Separate galaxies by their LSS classifications
#
# ### $V^2$

# %%
wall_v2 = catalog_main['vflag_V2'] == 0
void_v2 = catalog_main['vflag_V2'] == 1
edge_v2 = catalog_main['vflag_V2'] == 2
out_v2 = catalog_main['vflag_V2'] == 9

# %% [markdown]
# ### VoidFinder

# %%
wall_vf = catalog_main['vflag_VF'] == 0
void_vf = catalog_main['vflag_VF'] == 1
edge_vf = catalog_main['vflag_VF'] == 2
out_vf = catalog_main['vflag_VF'] == 9

# %%
del catalog_main, catalog_north, data

# %% [markdown]
# # Fit the color distributions with skewnormal distributions
#
# Both one- and two-parent models
#
# This is a bimodal distribution

# %%
gr_bins = np.arange(0, 1.25, 0.02)

# %% [markdown]
# ### 1-parent model

# %%
gr_fit_bounds1 = [[0.1, 10],    # s ........ Gaussian 1 to 2 scale factor
                  [100, 10000], # a ........ Gaussian a amplitude
                  [0, 0.75],    # mu_a ..... Gaussian a location
                  [1e-5, 2],    # sigma_a .. Gaussian a scale
                  [-10, 10],    # skew_a ... Gaussian a skew
                  [100, 10000], # b ........ Gaussian b amplitude
                  [0.75, 1.25], # mu_b ..... Gaussian b location
                  [1e-5, 1],    # sigma_b .. Gaussian b scale
                  [-10, 10]]    # skew_b ... Gaussian b skew

V2_gr_bestfit1 = Model_1_fit(gr_fit_bounds1, 
                             gr_NSA[wall_v2], 
                             gr_NSA[void_v2], 
                             gr_bins, 
                             2)

V2_gr_bestfit1
# Out:
# running minimizer...this might take a few minutes...
#       fun: 1075.382051575673
#  hess_inv: <9x9 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 5.39284887e-01, -1.84174625e-03,  1.89395451e+00, -9.30185707e-02,
#         2.16959962e-01, -6.41193256e-03, -1.75652985e+00,  4.81531970e-01,
#        -4.51109375e-02])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 3110
#       nit: 236
#      njev: 311
#    status: 0
#   success: True
#         x: array([ 2.40755603e+00,  1.15592141e+03,  4.18436466e-01,  2.32891007e-01,
#         1.20017693e+00,  8.83919721e+02,  9.61960886e-01,  1.36418686e-01,
#        -2.24278214e+00])

# %%
Model_1_plot(V2_gr_bestfit1.x, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$')

# %%
gr_fit_bounds1 = [[0.1, 10],    # s ........ Gaussian 1 to 2 scale factor
                  [100, 10000], # a ........ Gaussian a amplitude
                  [0, 0.75],    # mu_a ..... Gaussian a location
                  [1e-5, 2],    # sigma_a .. Gaussian a scale
                  [-10, 10],    # skew_a ... Gaussian a skew
                  [100, 10000], # b ........ Gaussian b amplitude
                  [0.75, 1.25], # mu_b ..... Gaussian b location
                  [1e-5, 1],    # sigma_b .. Gaussian b scale
                  [-10, 10]]    # skew_b ... Gaussian b skew

VF_gr_bestfit1 = Model_1_fit(gr_fit_bounds1, 
                             gr_NSA[wall_vf], 
                             gr_NSA[void_vf], 
                             gr_bins, 
                             2)

VF_gr_bestfit1
# Out:
# running minimizer...this might take a few minutes...
#       fun: 4698.212852052053
#  hess_inv: <9x9 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.39451765e+00, -2.09185994e-03,  7.03948900e-02, -4.65597623e+00,
#         3.80168788e-01, -1.27330605e-03,  5.66633386e+00,  1.74246452e+01,
#         3.15230866e-01])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 2780
#       nit: 221
#      njev: 278
#    status: 0
#   success: True
#         x: array([ 3.54402608e-01,  2.74524245e+03,  4.19710898e-01,  2.28478194e-01,
#         1.16343625e+00,  2.10350378e+03,  9.60399785e-01,  1.36282068e-01,
#        -2.31348569e+00])

# %%
Model_1_plot(VF_gr_bestfit1.x, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder')

# %% [markdown]
# ### Nested sampling of Likelihood and Priors

# %% [markdown]
# #### V$^2$

# %%
def prior_xform1_bi_V2(u):
    '''
    Priors for the 9 parameters of bimodel M1.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    s = uniform(0.1, 10, u[0])
    
    a = jeffreys(500, 5000, u[1])
    mu_a = uniform(0, 0.75, u[2])
    sigma_a = uniform(0.01, 3, u[3])
    skew_a = uniform(-5, 5, u[4])
    
    b = jeffreys(100, 5000, u[5])
    mu_b = uniform(0.75, 1.25, u[6])
    sigma_b = uniform(0.01, 3, u[7])
    skew_b = uniform(-5, 0, u[8])

    return s, a, mu_a, sigma_a, skew_a, b, mu_b, sigma_b, skew_b

# %%
Model_1_sampler(prior_xform1_bi_V2, 
                gr_NSA[wall_v2], 
                gr_NSA[void_v2], 
                gr_bins, 
                2, 
                '_gr_V2')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 45658it [22:10, 34.32it/s, batch: 8 | bound: 1219 | nc: 13 | ncall: 1070398 | eff(%):  4.266 | loglstar: -1085.314 < -1075.864 < -1077.236 | logz: -1128.014 +/-  0.431 | stop:  0.966]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model1_gr_V2'

# %%
temp_infile = open('dynesty_output/sampler_results_model1_gr_V2.pickle', 'rb')
dres1_V2_gr = pickle.load(temp_infile)
temp_infile.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 temp_infile = open('dynesty_output/sampler_results_model1_gr_V2.pickle', 'rb')
# ----> 2 dres1_V2_gr = pickle.load(temp_infile)
#       3 temp_infile.close()
#
# TypeError: 'Results' object does not support item assignment

# %%
labels1_bi = ['s', 'a', r'$\mu_a$', r'$\sigma_a$', 'skew$_a$', 
                   'b', r'$\mu_b$', r'$\sigma_b$', 'skew$_b$']
labels2_bi = ['$a_1$', r'$\mu_{1a}$', r'$\sigma_{1a}$', 'skew$_{1a}$', 
              '$b_1$', r'$\mu_{1b}$', r'$\sigma_{1b}$', 'skew$_{1b}$', 
              '$a_2$', r'$\mu_{2a}$', r'$\sigma_{2a}$', 'skew$_{2a}$', 
              '$b_2$', r'$\mu_{2b}$', r'$\sigma_{2b}$', 'skew$_{2b}$']

# %%
n_params = len(labels1_bi)

fig, axes = dyplot.cornerplot(dres1_V2_gr, smooth=0.03, 
                              labels=labels1_bi, 
                              # truths=V2_gr_bestfit1.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
n_params = len(labels1_bi)

fig, axes = dyplot.traceplot(dres1_V2_gr, 
                             labels=labels1_bi, 
                             # truths=V2_gr_bestfit1.x,
                             fig=plt.subplots(n_params, 2, figsize=(n_params, 2.6*n_params)), 
                             thin=10)

fig.tight_layout();

# %%
lnzM1_V2_gr = dres1_V2_gr.logz[-1]
lnzM1_V2_gr
# Out:
# -1128.0280919113243

# %%
V2_gr_bestfit1_dynesty,_ = dyfunc.mean_and_cov(dres1_V2_gr.samples, 
                                               np.exp(dres1_V2_gr.logwt - lnzM1_V2_gr))

V2_gr_bestfit1_dynesty
# Out:
# array([ 2.40761248e+00,  1.15578074e+03,  4.18473672e-01,  2.32861170e-01,
#         1.19987118e+00,  8.84042839e+02,  9.61961638e-01,  1.36455184e-01,
#        -2.24365344e+00])

# %%
'''
Model_1_plot(V2_gr_bestfit1.x, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$ (minimize)')
'''
Model_1_plot(V2_gr_bestfit1_dynesty, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$ (Dynesty)')

# %% [markdown]
# #### VoidFinder

# %%
def prior_xform1_bi_VF(u):
    '''
    Priors for the 9 parameters of bimodel M1.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    s = uniform(0.1, 5, u[0])
    
    a = jeffreys(500, 10000, u[1])
    mu_a = uniform(0, 0.75, u[2])
    sigma_a = uniform(0.01, 3, u[3])
    skew_a = uniform(0, 5, u[4])
    
    b = jeffreys(500, 10000, u[5])
    mu_b = uniform(0.75, 1.25, u[6])
    sigma_b = uniform(0.01, 2, u[7])
    skew_b = uniform(-5, 0, u[8])

    return s, a, mu_a, sigma_a, skew_a, b, mu_b, sigma_b, skew_b

# %%
Model_1_sampler(prior_xform1_bi_VF, 
                gr_NSA[wall_vf], 
                gr_NSA[void_vf], 
                gr_bins, 
                2, 
                '_gr_VoidFinder')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 46685it [09:49, 79.22it/s, batch: 8 | bound: 531 | nc: 1 | ncall: 452093 | eff(%): 10.326 | loglstar: -4708.502 < -4698.573 < -4700.690 | logz: -4751.053 +/-  0.430 | stop:  0.837]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model1_gr_VoidFinder'

# %%
temp_infile = open('dynesty_output/sampler_results_model1_gr_VoidFinder.pickle', 'rb')
dres1_VF_gr = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels1_bi)

fig, axes = dyplot.cornerplot(dres1_VF_gr, smooth=0.03, 
                              labels=labels1_bi, 
                              truths=VF_gr_bestfit1.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
lnzM1_VF_gr = dres1_VF_gr.logz[-1]
lnzM1_VF_gr
# Out:
# -4751.012223093637

# %%
VF_gr_bestfit1_dynesty,_ = dyfunc.mean_and_cov(dres1_VF_gr.samples, 
                                               np.exp(dres1_VF_gr.logwt - lnzM1_VF_gr))

VF_gr_bestfit1_dynesty
# Out:
# array([ 3.54384107e-01,  2.74472174e+03,  4.19712520e-01,  2.28450762e-01,
#         1.16331060e+00,  2.10430682e+03,  9.60420825e-01,  1.36356744e-01,
#        -2.31575519e+00])

# %%
Model_1_plot(VF_gr_bestfit1.x, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder (minimize)')

Model_1_plot(VF_gr_bestfit1_dynesty, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder (Dynesty)')

# %% [markdown]
# ## 2-parent model

# %%
# 1 = wall, 2 = void

gr_fit_bounds2 = [[100, 5000],  # a1 ........ Gaussian A1 amplitude
                  [0, 0.7],     # mu_a1 ..... Gaussian A1 location
                  [0.01, 10],   # sigma_a1 .. Gaussian A1 scale
                  [-10, 10],     # skew_a1 ... Gaussian A1 skew
                  [500, 10000], # b1 ........ Gaussian B1 amplitude
                  [0.7, 1.25],  # mu_b1 ..... Gaussian B1 location
                  [0.001, 3],   # sigma_b1 .. Gaussian B1 scale
                  [-5, 5],      # skew_b1 ... Gaussian B1 skew
                  [2400, 2800], #[100, 8000], # a2 ........ Gaussian A2 amplitude (2600)
                  [0.35, 0.45], #[0.2, 0.7],    # mu_a2 ..... Gaussian A2 location (0.40)
                  [0.18, 0.28], #[0.01, 10],    # sigma_a2 .. Gaussian A2 scale (0.23)
                  [1, 2], #[-5, 10],      # skew_a2 ... Gaussian A2 skew (1.29)
                  [2000, 2400], #[500, 10000],  # b2 ........ Gaussian B2 amplitude (2200)
                  [0.9, 1.1], #[0.7, 1.25], # mu_b2 ..... Gaussian B2 location (0.96)
                  [0.1, 0.2], #[0.01, 3],    # sigma_b2 .. Gaussian B2 scale (0.15)
                  [-3.5, -1.5]] #[-10, 5]]     # skew_b2 ... Gaussian B2 skew (-2.5)

V2_gr_bestfit2 = Model_2_fit(gr_fit_bounds2, 
                             gr_NSA[wall_v2], 
                             gr_NSA[void_v2], 
                             gr_bins, 
                             2)

V2_gr_bestfit2
# Out:
# running minimizer...this might take a few minutes...
#       fun: 1090.8595472103245
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-3.70709746e-01, -6.24768291e+00, -9.71886039e-01, -1.78788470e+00,
#         7.74920418e-01,  9.65276281e+00, -3.71169335e+00,  1.29830369e-02,
#         1.26625739e-01, -2.68867098e+00, -2.18178684e+00, -2.15168258e+00,
#         4.96498408e-01, -1.68946143e+01, -4.75324669e+00, -7.00833884e-01])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 9027
#       nit: 462
#      njev: 531
#    status: 0
#   success: True
#         x: array([ 9.47076245e+02,  3.80170638e-01,  2.41039989e-01,  1.50145707e+00,
#         1.10248255e+03,  9.77004995e-01,  1.77475214e-01, -3.25198884e+00,
#         2.67505461e+03,  4.02258856e-01,  2.32325711e-01,  1.29334434e+00,
#         2.26432538e+03,  9.63225509e-01,  1.48011677e-01, -2.48116165e+00])

# %%
Model_2_plot(V2_gr_bestfit2.x, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$')

# %%
# 1 = wall, 2 = void

gr_fit_bounds2 = [[1000, 5000],  # a1 ........ Gaussian A1 amplitude
                  [0.2, 0.7],    # mu_a1 ..... Gaussian A1 location
                  [0.01, 1],    # sigma_a1 .. Gaussian A1 scale
                  [0, 5],      # skew_a1 ... Gaussian A1 skew
                  [1000, 5000],  # b1 ........ Gaussian B1 amplitude
                  [0.7, 1.25], # mu_b1 ..... Gaussian B1 location
                  [0.01, 0.2],    # sigma_b1 .. Gaussian B1 scale
                  [-5, 0],      # skew_b1 ... Gaussian B1 skew
                  [1000, 1200], #[500, 5000],  # a2 ........ Gaussian A2 amplitude (1100)
                  [0.25, 0.45], #[0, 0.7],    # mu_a2 ..... Gaussian A2 location (0.37)
                  [0.1, 0.3], #[0.1, 5],    # sigma_a2 .. Gaussian A2 scale (0.23)
                  [0, 2], #[0, 10],      # skew_a2 ... Gaussian A2 skew (1.4)
                  [500, 700], #[100, 5000],  # b2 ........ Gaussian B2 amplitude (630)
                  [0.85, 1.05], #[0.7, 1.25], # mu_b2 ..... Gaussian B2 location (0.96)
                  [0.1, 0.2], #[0.01, 5],    # sigma_b2 .. Gaussian B2 scale (0.16)
                  [-5, 0]] #[-10, 0]]    # skew_b2 ... Gaussian B2 skew (-2.6)

VF_gr_bestfit2 = Model_2_fit(gr_fit_bounds2, 
                             gr_NSA[wall_vf], 
                             gr_NSA[void_vf], 
                             gr_bins, 
                             2)

VF_gr_bestfit2
# Out:
# running minimizer...this might take a few minutes...
#       fun: 891.281753038825
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 1.76762165e-01, -1.36136350e+01, -4.35205493e+01, -1.65141501e+00,
#         9.26557526e-03, -8.17287851e+00,  8.28527505e+01, -3.47461084e-01,
#        -6.30161437e-01,  1.19669949e+01,  2.71893669e+01, -1.09660505e+01,
#        -3.30510112e-01, -1.43321358e+01, -3.17407398e+01,  1.95697681e+01])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 7565
#       nit: 359
#      njev: 445
#    status: 0
#   success: True
#         x: array([ 2.63214412e+03,  4.48082924e-01,  2.21211563e-01,  1.01918283e+00,
#         2.22625407e+03,  9.60513876e-01,  1.29306080e-01, -2.21186132e+00,
#         1.12827998e+03,  3.84899591e-01,  2.28938779e-01,  1.26256530e+00,
#         5.72222515e+02,  9.47088204e-01,  1.39487933e-01, -1.93256147e+00])

# %%
Model_2_plot(VF_gr_bestfit2.x, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder')

# %% [markdown]
# ### Nested sampling of Likelihood and Priors

# %% [markdown]
# #### V$^2$

# %%
def prior_xform2_bi_V2(u):
    '''
    Priors for the 16 parameters of bimodal M2.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    a1 = jeffreys(100, 2500, u[0])
    mu_a1 = uniform(0.2, 0.7, u[1])
    sigma_a1 = uniform(0.01, 1, u[2])
    skew_a1 = uniform(0, 5, u[3])

    b1 = jeffreys(500, 5000, u[4])
    mu_b1 = uniform(0.7, 1.2, u[5])
    sigma_b1 = uniform(0.01, 1, u[6])
    skew_b1 = uniform(-5, 0, u[7])
    
    a2 = jeffreys(1000, 5000, u[8])
    mu_a2 = uniform(0.2, 0.7, u[9])
    sigma_a2 = uniform(0.01, 1, u[10])
    skew_a2 = uniform(0, 5, u[11])

    b2 = jeffreys(1000, 5000, u[12])
    mu_b2 = uniform(0.7, 1.2, u[13])
    sigma_b2 = uniform(0.01, 1, u[14])
    skew_b2 = uniform(-5, 0, u[15])

    return a1, mu_a1, sigma_a1, skew_a1, b1, mu_b1, sigma_b1, skew_b1, \
           a2, mu_a2, sigma_a2, skew_a2, b2, mu_b2, sigma_b2, skew_b2

# %%
Model_2_sampler(prior_xform2_bi_V2, 
                gr_NSA[wall_v2], 
                gr_NSA[void_v2], 
                gr_bins, 
                2, 
                '_gr_V2')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 11684it [03:11, 48.49it/s, batch: 0 | bound: 150 | nc: 25 | ncall: 267677 | eff(%):  4.357 | loglstar:   -inf < -5476.956 <    inf | logz: -5505.752 +/-  0.337 | dlogz: 2751.199 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12347it [03:24, 56.58it/s, batch: 0 | bound: 160 | nc: 25 | ncall: 285584 | eff(%):  4.316 | loglstar:   -inf < -4797.818 <    inf | logz: -4828.673 +/-  0.346 | dlogz: 2073.172 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 12764it [03:33, 57.29it/s, batch: 0 | bound: 167 | nc: 25 | ncall: 298056 | eff(%):  4.275 | loglstar:   -inf < -4402.424 <    inf | logz: -4433.831 +/-  0.350 | dlogz: 1677.310 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13277it [03:45, 58.64it/s, batch: 0 | bound: 177 | nc: 25 | ncall: 314555 | eff(%):  4.214 | loglstar:   -inf < -3966.677 <    inf | logz: -3998.653 +/-  0.353 | dlogz: 1506.564 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13648it [03:54, 60.99it/s, batch: 0 | bound: 183 | nc: 25 | ncall: 326994 | eff(%):  4.167 | loglstar:   -inf < -3697.581 <    inf | logz: -3731.297 +/-  0.362 | dlogz: 1447.610 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13847it [04:00, 55.73it/s, batch: 0 | bound: 187 | nc: 25 | ncall: 335352 | eff(%):  4.123 | loglstar:   -inf < -3574.596 <    inf | logz: -3608.092 +/-  0.360 | dlogz: 1323.280 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14087it [04:07, 54.68it/s, batch: 0 | bound: 193 | nc: 25 | ncall: 345545 | eff(%):  4.071 | loglstar:   -inf < -3434.798 <    inf | logz: -3469.382 +/-  0.368 | dlogz: 1570.234 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14151it [04:10, 43.33it/s, batch: 0 | bound: 195 | nc: 25 | ncall: 349449 | eff(%):  4.044 | loglstar:   -inf < -3392.504 <    inf | logz: -3426.763 +/-  0.364 | dlogz: 1526.780 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14282it [04:15, 58.45it/s, batch: 0 | bound: 198 | nc: 25 | ncall: 355846 | eff(%):  4.008 | loglstar:   -inf < -3321.713 <    inf | logz: -3355.302 +/-  0.362 | dlogz: 1454.644 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14562it [04:21, 58.95it/s, batch: 0 | bound: 203 | nc: 25 | ncall: 365352 | eff(%):  3.980 | loglstar:   -inf < -3157.699 <    inf | logz: -3192.479 +/-  0.365 | dlogz: 1291.409 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14589it [04:24, 21.33it/s, batch: 0 | bound: 205 | nc: 25 | ncall: 368971 | eff(%):  3.949 | loglstar:   -inf < -3143.288 <    inf | logz: -3178.384 +/-  0.370 | dlogz: 1277.607 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14650it [04:27, 43.25it/s, batch: 0 | bound: 207 | nc: 25 | ncall: 373838 | eff(%):  3.914 | loglstar:   -inf < -3114.545 <    inf | logz: -3149.151 +/-  0.365 | dlogz: 1247.826 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14691it [04:30, 35.27it/s, batch: 0 | bound: 209 | nc: 25 | ncall: 377270 | eff(%):  3.889 | loglstar:   -inf < -3094.144 <    inf | logz: -3128.818 +/-  0.368 | dlogz: 1227.512 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14893it [04:36, 57.81it/s, batch: 0 | bound: 213 | nc: 25 | ncall: 386470 | eff(%):  3.849 | loglstar:   -inf < -2989.620 <    inf | logz: -3024.879 +/-  0.370 | dlogz: 1123.179 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14989it [04:39, 51.95it/s, batch: 0 | bound: 216 | nc: 25 | ncall: 390727 | eff(%):  3.831 | loglstar:   -inf < -2945.806 <    inf | logz: -2980.468 +/-  0.368 | dlogz: 1078.335 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15322it [04:50, 57.11it/s, batch: 0 | bound: 222 | nc: 25 | ncall: 406312 | eff(%):  3.766 | loglstar:   -inf < -2789.590 <    inf | logz: -2826.108 +/-  0.375 | dlogz: 923.652 >  0.010]   /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15528it [04:56, 57.96it/s, batch: 0 | bound: 226 | nc: 25 | ncall: 413871 | eff(%):  3.747 | loglstar:   -inf < -2705.067 <    inf | logz: -2740.867 +/-  0.374 | dlogz: 987.912 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15735it [05:02, 57.12it/s, batch: 0 | bound: 230 | nc: 25 | ncall: 422969 | eff(%):  3.716 | loglstar:   -inf < -2614.875 <    inf | logz: -2651.574 +/-  0.379 | dlogz: 898.431 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15801it [05:07, 43.08it/s, batch: 0 | bound: 232 | nc: 25 | ncall: 430500 | eff(%):  3.666 | loglstar:   -inf < -2589.777 <    inf | logz: -2625.920 +/-  0.377 | dlogz: 872.369 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16814it [05:31, 57.72it/s, batch: 0 | bound: 247 | nc: 25 | ncall: 464424 | eff(%):  3.617 | loglstar:   -inf < -2233.997 <    inf | logz: -2272.491 +/-  0.389 | dlogz: 674.981 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17086it [05:38, 58.44it/s, batch: 0 | bound: 252 | nc: 25 | ncall: 475171 | eff(%):  3.592 | loglstar:   -inf < -2145.332 <    inf | logz: -2184.908 +/-  0.392 | dlogz: 756.318 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17687it [05:54, 59.81it/s, batch: 0 | bound: 261 | nc: 25 | ncall: 496621 | eff(%):  3.558 | loglstar:   -inf < -1976.275 <    inf | logz: -2016.346 +/-  0.396 | dlogz: 689.932 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17744it [06:01, 28.72it/s, batch: 0 | bound: 263 | nc: 25 | ncall: 508488 | eff(%):  3.486 | loglstar:   -inf < -1959.404 <    inf | logz: -1999.108 +/-  0.395 | dlogz: 672.461 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17808it [06:06, 42.32it/s, batch: 0 | bound: 265 | nc: 25 | ncall: 514748 | eff(%):  3.456 | loglstar:   -inf < -1944.876 <    inf | logz: -1985.053 +/-  0.395 | dlogz: 658.335 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18619it [06:26, 55.10it/s, batch: 0 | bound: 277 | nc: 25 | ncall: 543238 | eff(%):  3.424 | loglstar:   -inf < -1751.656 <    inf | logz: -1792.953 +/-  0.402 | dlogz: 478.388 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20010it [06:58, 46.98it/s, batch: 0 | bound: 297 | nc: 25 | ncall: 584163 | eff(%):  3.422 | loglstar:   -inf < -1494.779 <    inf | logz: -1538.843 +/-  0.416 | dlogz: 293.861 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20589it [07:14, 55.63it/s, batch: 0 | bound: 306 | nc: 25 | ncall: 605169 | eff(%):  3.399 | loglstar:   -inf < -1412.849 <    inf | logz: -1458.178 +/-  0.422 | dlogz: 336.989 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22834it [08:04, 59.78it/s, batch: 0 | bound: 337 | nc: 25 | ncall: 675157 | eff(%):  3.380 | loglstar:   -inf < -1200.660 <    inf | logz: -1250.246 +/-  0.440 | dlogz: 158.660 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25035it [08:56, 57.67it/s, batch: 0 | bound: 368 | nc: 25 | ncall: 747309 | eff(%):  3.348 | loglstar:   -inf < -1077.074 <    inf | logz: -1130.300 +/-  0.457 | dlogz: 95.723 >  0.010]    /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 57154it [23:52, 39.91it/s, batch: 6 | bound: 760 | nc: 25 | ncall: 1563620 | eff(%):  3.655 | loglstar: -928.763 < -917.384 < -920.441 | logz: -994.764 +/-  0.527 | stop:  0.953]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model2_gr_V2'

# %%
temp_infile = open('dynesty_output/sampler_results_model2_gr_V2.pickle', 'rb')
dres2_V2_gr = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.cornerplot(dres2_V2_gr, smooth=0.03, 
                              labels=labels2_bi, 
                              truths=V2_gr_bestfit2.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.traceplot(dres2_V2_gr, 
                             labels=labels2_bi, 
                             truths=V2_gr_bestfit2.x,
                             fig=plt.subplots(n_params, 2, figsize=(0.5*n_params, 2.6*n_params)), 
                             thin=10)

fig.tight_layout();

# %%
lnzM2_V2_gr = dres2_V2_gr.logz[-1]
lnzM2_V2_gr
# Out:
# -994.747391956942

# %%
V2_gr_bestfit2_dynesty,_ = dyfunc.mean_and_cov(dres2_V2_gr.samples, 
                                               np.exp(dres2_V2_gr.logwt - lnzM2_V2_gr))

V2_gr_bestfit2_dynesty
# Out:
# array([ 1.15915377e+03,  4.33849474e-01,  2.32679399e-01,  1.11977024e+00,
#         8.80927732e+02,  9.64873453e-01,  1.31297204e-01, -2.16305618e+00,
#         2.78085586e+03,  4.13437609e-01,  2.32092944e-01,  1.22164267e+00,
#         2.13004682e+03,  9.60425418e-01,  1.38210774e-01, -2.26571389e+00])

# %%
Model_2_plot(V2_gr_bestfit2.x, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$ (minimize)')

Model_2_plot(V2_gr_bestfit2_dynesty, 
             gr_NSA[wall_v2], 
             gr_NSA[void_v2], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='$V^2$ (Dynesty)')

# %% [markdown]
# ##### VoidFinder

# %%
def prior_xform2_bi_VF(u):
    '''
    Priors for the 16 parameters of bimodal M2.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    a1 = jeffreys(500, 5000, u[0])
    mu_a1 = uniform(0.2, 0.7, u[1])
    sigma_a1 = uniform(0.01, 1, u[2])
    skew_a1 = uniform(0, 5, u[3])

    b1 = jeffreys(500, 5000, u[4])
    mu_b1 = uniform(0.7, 1.2, u[5])
    sigma_b1 = uniform(0.01, 1, u[6])
    skew_b1 = uniform(-5, 0, u[7])
    
    a2 = jeffreys(100, 5000, u[8])
    mu_a2 = uniform(0.2, 0.7, u[9])
    sigma_a2 = uniform(0.01, 1, u[10])
    skew_a2 = uniform(0, 5, u[11])

    b2 = jeffreys(100, 1000, u[12])
    mu_b2 = uniform(0.7, 1.2, u[13])
    sigma_b2 = uniform(0.01, 1, u[14])
    skew_b2 = uniform(-5, 0, u[15])

    return a1, mu_a1, sigma_a1, skew_a1, b1, mu_b1, sigma_b1, skew_b1, \
           a2, mu_a2, sigma_a2, skew_a2, b2, mu_b2, sigma_b2, skew_b2

# %%
Model_2_sampler(prior_xform2_bi_VF, 
                gr_NSA[wall_vf], 
                gr_NSA[void_vf], 
                gr_bins, 
                2, 
                '_gr_VoidFinder')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 1747it [00:11, 54.23it/s, batch: 0 | bound: 0 | nc: 102 | ncall: 16862 | eff(%): 10.062 | loglstar:   -inf < -83320.747 <    inf | logz: -83331.026 +/-  0.200 | dlogz: 54692.957 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11198it [03:15, 57.49it/s, batch: 0 | bound: 143 | nc: 25 | ncall: 254866 | eff(%):  4.385 | loglstar:   -inf < -6601.861 <    inf | logz: -6630.191 +/-  0.330 | dlogz: 3749.934 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 12408it [03:40, 58.81it/s, batch: 0 | bound: 164 | nc: 25 | ncall: 291153 | eff(%):  4.254 | loglstar:   -inf < -4965.702 <    inf | logz: -4996.943 +/-  0.348 | dlogz: 2135.935 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 12687it [03:47, 54.43it/s, batch: 0 | bound: 171 | nc: 25 | ncall: 300853 | eff(%):  4.210 | loglstar:   -inf < -4629.514 <    inf | logz: -4660.019 +/-  0.346 | dlogz: 2026.565 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 12811it [03:51, 57.50it/s, batch: 0 | bound: 174 | nc: 25 | ncall: 306136 | eff(%):  4.178 | loglstar:   -inf < -4507.619 <    inf | logz: -4538.786 +/-  0.350 | dlogz: 1958.159 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13384it [04:02, 58.21it/s, batch: 0 | bound: 183 | nc: 25 | ncall: 322299 | eff(%):  4.146 | loglstar:   -inf < -3945.037 <    inf | logz: -3976.846 +/-  0.355 | dlogz: 1897.973 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13454it [04:05, 52.37it/s, batch: 0 | bound: 185 | nc: 25 | ncall: 326208 | eff(%):  4.118 | loglstar:   -inf < -3886.049 <    inf | logz: -3918.410 +/-  0.355 | dlogz: 1839.477 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14120it [04:18, 59.55it/s, batch: 0 | bound: 195 | nc: 25 | ncall: 345550 | eff(%):  4.080 | loglstar:   -inf < -3344.700 <    inf | logz: -3377.899 +/-  0.360 | dlogz: 1523.924 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14144it [04:20, 21.90it/s, batch: 0 | bound: 197 | nc: 25 | ncall: 348546 | eff(%):  4.052 | loglstar:   -inf < -3321.860 <    inf | logz: -3356.040 +/-  0.363 | dlogz: 1502.405 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14257it [04:24, 56.88it/s, batch: 0 | bound: 200 | nc: 25 | ncall: 353266 | eff(%):  4.030 | loglstar:   -inf < -3251.749 <    inf | logz: -3285.342 +/-  0.362 | dlogz: 1431.123 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14378it [04:28, 58.42it/s, batch: 0 | bound: 203 | nc: 25 | ncall: 359264 | eff(%):  3.997 | loglstar:   -inf < -3171.717 <    inf | logz: -3206.725 +/-  0.368 | dlogz: 1352.981 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14397it [04:31, 13.71it/s, batch: 0 | bound: 205 | nc: 25 | ncall: 363291 | eff(%):  3.957 | loglstar:   -inf < -3163.255 <    inf | logz: -3197.057 +/-  0.364 | dlogz: 1342.557 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15053it [04:44, 59.03it/s, batch: 0 | bound: 215 | nc: 25 | ncall: 381707 | eff(%):  3.938 | loglstar:   -inf < -2780.988 <    inf | logz: -2816.414 +/-  0.373 | dlogz: 1134.888 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15167it [04:49, 58.28it/s, batch: 0 | bound: 218 | nc: 25 | ncall: 389800 | eff(%):  3.886 | loglstar:   -inf < -2720.952 <    inf | logz: -2756.581 +/-  0.375 | dlogz: 1074.821 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15518it [04:58, 61.19it/s, batch: 0 | bound: 224 | nc: 25 | ncall: 402334 | eff(%):  3.852 | loglstar:   -inf < -2531.485 <    inf | logz: -2568.252 +/-  0.379 | dlogz: 977.249 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15577it [05:01, 41.80it/s, batch: 0 | bound: 226 | nc: 25 | ncall: 407437 | eff(%):  3.818 | loglstar:   -inf < -2506.471 <    inf | logz: -2542.103 +/-  0.373 | dlogz: 950.522 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16004it [05:10, 59.65it/s, batch: 0 | bound: 233 | nc: 25 | ncall: 420542 | eff(%):  3.801 | loglstar:   -inf < -2323.026 <    inf | logz: -2359.941 +/-  0.379 | dlogz: 767.608 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16109it [05:17, 56.19it/s, batch: 0 | bound: 236 | nc: 25 | ncall: 429982 | eff(%):  3.742 | loglstar:   -inf < -2280.543 <    inf | logz: -2317.447 +/-  0.381 | dlogz: 724.859 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16278it [05:22, 57.86it/s, batch: 0 | bound: 240 | nc: 25 | ncall: 437547 | eff(%):  3.716 | loglstar:   -inf < -2211.744 <    inf | logz: -2249.090 +/-  0.382 | dlogz: 656.187 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17341it [05:45, 54.52it/s, batch: 0 | bound: 256 | nc: 25 | ncall: 471647 | eff(%):  3.673 | loglstar:   -inf < -1875.383 <    inf | logz: -1914.562 +/-  0.392 | dlogz: 557.484 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18013it [06:04, 60.28it/s, batch: 0 | bound: 266 | nc: 25 | ncall: 499601 | eff(%):  3.602 | loglstar:   -inf < -1713.812 <    inf | logz: -1754.136 +/-  0.397 | dlogz: 458.491 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18939it [06:26, 60.17it/s, batch: 0 | bound: 280 | nc: 25 | ncall: 532094 | eff(%):  3.556 | loglstar:   -inf < -1527.973 <    inf | logz: -1570.116 +/-  0.406 | dlogz: 343.185 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19743it [06:44, 58.11it/s, batch: 0 | bound: 292 | nc: 25 | ncall: 558583 | eff(%):  3.531 | loglstar:   -inf < -1402.523 <    inf | logz: -1446.285 +/-  0.413 | dlogz: 329.805 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20305it [07:01, 57.81it/s, batch: 0 | bound: 301 | nc: 25 | ncall: 584111 | eff(%):  3.473 | loglstar:   -inf < -1334.040 <    inf | logz: -1378.371 +/-  0.417 | dlogz: 260.873 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20944it [07:18, 58.05it/s, batch: 0 | bound: 311 | nc: 25 | ncall: 609314 | eff(%):  3.434 | loglstar:   -inf < -1268.062 <    inf | logz: -1313.613 +/-  0.421 | dlogz: 236.873 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22475it [07:52, 58.63it/s, batch: 0 | bound: 333 | nc: 25 | ncall: 659163 | eff(%):  3.407 | loglstar:   -inf < -1146.096 <    inf | logz: -1194.402 +/-  0.435 | dlogz: 175.971 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24897it [08:44, 56.17it/s, batch: 0 | bound: 367 | nc: 25 | ncall: 735513 | eff(%):  3.383 | loglstar:   -inf < -1020.950 <    inf | logz: -1073.369 +/-  0.453 | dlogz: 86.158 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 49716it [19:11, 43.19it/s, batch: 4 | bound: 672 | nc: 25 | ncall: 1366426 | eff(%):  3.638 | loglstar: -889.452 < -879.543 < -882.118 | logz: -955.735 +/-  0.526 | stop:  0.965]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model2_gr_VoidFinder'

# %%
temp_infile = open('dynesty_output/sampler_results_model2_gr_VoidFinder.pickle', 'rb')
dres2_VF_gr = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.cornerplot(dres2_VF_gr, smooth=0.03, 
                              labels=labels2_bi, 
                              truths=VF_gr_bestfit2.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
lnzM2_VF_gr = dres2_VF_gr.logz[-1]
lnzM2_VF_gr
# Out:
# -955.7524066554337

# %%
VF_gr_bestfit2_dynesty,_ = dyfunc.mean_and_cov(dres2_VF_gr.samples, 
                                               np.exp(dres2_VF_gr.logwt - lnzM2_VF_gr))

VF_gr_bestfit2_dynesty
# Out:
# array([ 2.57681256e+03,  4.40890285e-01,  2.22730305e-01,  1.07044406e+00,
#         2.27222578e+03,  9.61558515e-01,  1.32867666e-01, -2.29605660e+00,
#         1.15826231e+03,  3.81443392e-01,  2.36144686e-01,  1.33818718e+00,
#         5.60410024e+02,  9.50421038e-01,  1.41432127e-01, -2.10704802e+00])

# %%
Model_2_plot(VF_gr_bestfit2.x, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder (minimize)')

Model_2_plot(VF_gr_bestfit2_dynesty, 
             gr_NSA[wall_vf], 
             gr_NSA[void_vf], 
             gr_bins, 
             2, 
             xlabel_text='g - r', 
             title_text='VoidFinder (Dynesty)')

# %% [markdown]
# ## Bayes Factor

# %%
lnB12_V2_gr = lnzM1_V2_gr - lnzM2_V2_gr

B12_V2_gr = np.exp(lnB12_V2_gr)

print('V2 (g - r): B12 = {:.3g}; log(B12) = {:.3g}'.format(B12_V2_gr, np.log10(B12_V2_gr)))
# Out:
# V2 (g - r): B12 = 1.31e-58; log(B12) = -57.9

# %%
lnB12_VF_gr = lnzM1_VF_gr - lnzM2_VF_gr

B12_VF_gr = np.exp(lnB12_VF_gr)

print('VoidFinder (g - r): B12 = {:.3g}; log(B12) = {:.3f}'.format(B12_VF_gr, lnB12_VF_gr*np.log10(np.exp(1))))
# Out:
# VoidFinder (g - r): B12 = 0; log(B12) = -1648.260

# %% [markdown]
# So both VoidFinder and V$^2$ favor $\mathcal{M}_2$, in which the two data sets come from different parent distributions, although VoidFinder favors it much more than V$^2$.
