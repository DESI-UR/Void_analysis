# %% [markdown]
# Calculate the Bayes Factor for $u-r$ to determine whether the void and wall samples are drawn from the same or different parent distributions.

# %%
from astropy.table import Table
from astropy.io import fits

import numpy as np

import sys

import pickle

import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc

import matplotlib
import matplotlib.pyplot as plt

from functions import Model_1_plot, Model_2_plot, uniform, jeffreys, Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler
#from functions_gauss import Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler

np.set_printoptions(threshold=sys.maxsize)

# %%
matplotlib.rc('font', size=14)
matplotlib.rc('font', family='DejaVu Sans')

# %% [markdown]
# # Data

# %%
data_filename = '/home/codebind/Bootes/NSA_Full.fits'

hdu = fits.open(data_filename)
data = Table(hdu[1].data)
hdu.close()

# %% [markdown]
# ## Just keep the main SDSS DR7 footprint

# %%
# When the catalog is the NSA, only keep those objects which were originally in the DR7 LSS
catalog_SDSS = data[data['IN_DR7_LSS'] == 1]
del data

ra_boolean = np.logical_and(catalog_SDSS['RA'] > 110, catalog_SDSS['RA'] < 270)
catalog_north = catalog_SDSS[ra_boolean]
del catalog_SDSS

strip_boolean = np.logical_and.reduce([catalog_north['RA'] > 250, 
                                       catalog_north['RA'] < 269, 
                                       catalog_north['DEC'] > 51, 
                                       catalog_north['DEC'] < 67])
catalog_main = catalog_north[~strip_boolean]
del catalog_north

# %%
ur_NSA = np.array(catalog_main['u_r'])
del catalog_main

# %% [markdown]
# ### Kirshner Data

# %%
KNSA = Table.read('/home/codebind/Bootes/My Code/KNSA.txt', format = "ascii.commented_header")
K = KNSA['U-R']

# %% [markdown]
# # Fit the color distributions with skewnormal distributions
#
# Both one- and two-parent models
#
# This is a bimodal distribution

# %%
ur_bins = np.linspace(0, 5, 100)
k_bins = np.linspace(0,5, 35)

# %% [markdown]
# ### 1-parent model

# %%
ur_fit_bounds1 = [[1e-5, 1e-2],    # s ........ Gaussian 1 to 2 scale factor
                  [100, 50000], # a ........ Gaussian a amplitude
                  [1, 2.1],     # mu_a ..... Gaussian a location
                  [.01, 10],    # sigma_a .. Gaussian a scale
                  [-10, 10],      # skew_a ... Gaussian a skew
                  [500, 50000], # b ........ Gaussian b amplitude
                  [2.1, 3],   # mu_b ..... Gaussian b location
                  [.01, 10],    # sigma_b .. Gaussian b scale
                  [-10, 10]]      # skew_b ... Gaussian b skew

V2_ur_bestfit1 = Model_1_fit(ur_fit_bounds1, 
                             ur_NSA, 
                             K, 
                             ur_bins, 
                             k_bins,
                             2)

V2_ur_bestfit1
# Out:
# running minimizer...this might take a few minutes...
#       fun: 3296.606822264346
#  hess_inv: <9x9 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 2.25373242e+02, -2.95743907e-01,  1.42706996e+01, -8.11373871e+00,
#         2.66945792e+00, -1.93161150e-01,  3.56624243e+01, -4.72559802e+00,
#         9.96246860e+00])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 1910
#       nit: 113
#      njev: 191
#    status: 0
#   success: True
#         x: array([ 1.74506876e-03,  9.66126399e+03,  1.26580903e+00,  1.01290410e+00,
#         5.98069314e+00,  1.58421350e+04,  2.96513567e+00,  9.13392180e-01,
#        -5.32590709e+00])

# %%
Model_1_plot(V2_ur_bestfit1.x, 
             ur_NSA, 
             K, 
             ur_bins, 
             k_bins,
             2, 
             xlabel_text='u - r', 
             title_text='$V^2$')

# %% [markdown]
# ### Nested Samlping

# %% [markdown]
# #### VoidFinder

# %%
def prior_xform1_bi_VF(u):
    '''
    Priors for the 9 parameters of bimodel M1.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    s = uniform(1e-5, 1e-3, u[0])
    
    a = jeffreys(1000, 15000, u[1])
    mu_a = uniform(1, 2.2, u[2])
    sigma_a = uniform(.01, 50, u[3])
    skew_a = uniform(-10, 10, u[4])
    
    b = jeffreys(1000, 20000, u[5])
    mu_b = uniform(2.2, 4, u[6])
    sigma_b = uniform(.01, 50, u[7])
    skew_b = uniform(-10, 10, u[8])

    return s, a, mu_a, sigma_a, skew_a, b, mu_b, sigma_b, skew_b

# %%
Model_1_sampler(prior_xform1_bi_VF, 
                ur_NSA, 
                K, 
                ur_bins, 
                k_bins,
                2, 
                '_ur_VoidFinder')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 5552it [05:40, 16.30it/s, batch: 0 | bound: 93 | nc: 205 | ncall: 183894 | eff(%):  3.003 | loglstar:   -inf < -283269.199 <    inf | logz: -283281.946 +/-  0.111 | dlogz: 241173.186 >  0.010]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 Model_1_sampler(prior_xform1_bi_VF,
#       2                 ur_NSA,
#       3                 K,
#       4                 ur_bins,
#       5                 k_bins,
#       6                 2,
#       7                 '_ur_VoidFinder')
#
# File ~/Bootes/Void_analysis/nb/Taryn_Lovan/functions.py:815, in Model_1_sampler(prior_, data1, data2, bins1, bins2, peaks, fname_suffix)
#     804 print("running the nested sampler... this might take from minutes to hours...")
#     806 dsampler = dynesty.DynamicNestedSampler(logLjoint1_skew,
#     807                                         prior_,
#     808                                         ndim=1 + 4*peaks,
#    (...)
#     812                                         sample='auto'
#     813                                        )
# --> 815 dsampler.run_nested()
#     816 dres1 = dsampler.results
#     818 with open('dynesty_output/sampler_results_model1'+fname_suffix+'.pickle', 'wb') as dres1_file:
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/dynamicsampler.py:1664, in DynamicSampler.run_nested(self, nlive_init, maxiter_init, maxcall_init, dlogz_init, logl_max_init, n_effective_init, nlive_batch, wt_function, wt_kwargs, maxiter_batch, maxcall_batch, maxiter, maxcall, maxbatch, n_effective, stop_function, stop_kwargs, use_stop, save_bounds, print_progress, print_func, live_points)
#    1662 try:
#    1663     if not self.base:
# -> 1664         for results in self.sample_initial(
#    1665                 nlive=nlive_init,
#    1666                 dlogz=dlogz_init,
#    1667                 maxcall=maxcall_init,
#    1668                 maxiter=maxiter_init,
#    1669                 logl_max=logl_max_init,
#    1670                 live_points=live_points,
#    1671                 n_effective=n_effective_init):
#    1673             ncall += results.nc
#    1674             niter += 1
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/dynamicsampler.py:846, in DynamicSampler.sample_initial(self, nlive, update_interval, first_update, maxiter, maxcall, logl_max, dlogz, n_effective, live_points, save_samples, resume)
#     844 # Run the sampler internally as a generator.
#     845 for i in range(1):
# --> 846     for it, results in enumerate(
#     847             self.sampler.sample(maxiter=maxiter,
#     848                                 save_samples=save_samples,
#     849                                 maxcall=maxcall,
#     850                                 dlogz=dlogz)):
#     851         # Grab results.
#     852
#     853         # Save our base run (which we will use later).
#     854         add_info = dict(id=results.worst,
#     855                         u=results.ustar,
#     856                         v=results.vstar,
#    (...)
#     867                         bounditer=results.bounditer,
#     868                         scale=self.sampler.scale)
#     870         self.base_run.append(add_info)
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:740, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples)
#     735 loglstar_new = self.live_logl[worst]  # new likelihood
#     737 # Sample a new live point from within the likelihood constraint
#     738 # `logl > loglstar` using the bounding distribution and sampling
#     739 # method from our sampler.
# --> 740 u, v, logl, nc = self._new_point(loglstar_new)
#     741 ncall += nc
#     742 self.ncall += nc
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:360, in Sampler._new_point(self, loglstar)
#     357 ncall, nupdate = 0, 0
#     358 while True:
#     359     # Get the next point from the queue
# --> 360     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     361     ncall += nc
#     363     # Bounding checks.
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:343, in Sampler._get_point_value(self, loglstar)
#     341 # If the queue is empty, refill it.
#     342 if self.nqueue <= 0:
# --> 343     self._fill_queue(loglstar)
#     345 # Grab the earliest entry.
#     346 u, v, logl, nc, blob = self.queue.pop(0)
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:311, in Sampler._fill_queue(self, loglstar)
#     308 while self.nqueue < self.queue_size:
#     309     if self._beyond_unit_bound(loglstar):
#     310         # Propose points using the provided sampling/bounding options.
# --> 311         point, axes = self.propose_point(*args)
#     312         evolve_point = self.evolve_point
#     313     else:
#     314         # Propose/evaluate points directly from the unit cube.
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/nestedsamplers.py:602, in MultiEllipsoidSampler.propose_unif(self, *args)
#     600     u, idx = self.mell.sample(rstate=self.rstate)
#     601     # Check if the point is within the unit cube.
# --> 602     if unitcheck(u, nonb):
#     603         break  # if successful, we're done!
#     604 if self.ncdim != self.npdim:
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/utils.py:334, in unitcheck(u, nonbounded)
#     328 """Check whether `u` is inside the unit cube. Given a masked array
#     329 `nonbounded`, also allows periodic boundaries conditions to exceed
#     330 the unit cube."""
#     332 if nonbounded is None:
#     333     # No periodic boundary conditions provided.
# --> 334     return np.min(u) > 0 and np.max(u) < 1
#     335 else:
#     336     # Alternating periodic and non-periodic boundary conditions.
#     337     unb = u[nonbounded]
#
# File <__array_function__ internals>:180, in amin(*args, **kwargs)
#
# File ~/VAST/.eggs/numpy-1.22.4-py3.8-linux-x86_64.egg/numpy/core/fromnumeric.py:2916, in amin(a, axis, out, keepdims, initial, where)
#    2800 @array_function_dispatch(_amin_dispatcher)
#    2801 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2802          where=np._NoValue):
#    2803     """
#    2804     Return the minimum of an array or minimum along an axis.
#    2805
#    (...)
#    2914     6
#    2915     """
# -> 2916     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2917                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/VAST/.eggs/numpy-1.22.4-py3.8-linux-x86_64.egg/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      83         else:
#      84             return reduction(axis=axis, out=out, **passkwargs)
# ---> 86 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
temp_infile = open('dynesty_output/sampler_results_model1_ur_VoidFinder.pickle', 'rb')
dres1_VF_ur = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels1_bi)

fig, axes = dyplot.cornerplot(dres1_VF_ur, smooth=0.03, 
                              labels=labels1_bi, 
                              truths=VF_ur_bestfit1.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
lnzM1_VF_ur = dres1_VF_ur.logz[-1]
lnzM1_VF_ur
# Out:
# -4822.731347962

# %%
VF_ur_bestfit1_dynesty,_ = dyfunc.mean_and_cov(dres1_VF_ur.samples, 
                                               np.exp(dres1_VF_ur.logwt - lnzM1_VF_ur))

VF_ur_bestfit1_dynesty
# Out:
# array([ 3.54884306e-01,  8.79849117e+03,  1.38657647e+00,  7.45464859e-01,
#         2.04513391e+00,  3.28171488e+03,  2.71433372e+00,  2.20574396e-01,
#        -5.93174341e-01])

# %%
Model_1_plot(VF_ur_bestfit1.x, 
             ur_NSA[wall_vf], 
             ur_NSA[void_vf], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='VoidFinder (minimize)')

Model_1_plot(VF_ur_bestfit1_dynesty, 
             ur_NSA[wall_vf], 
             ur_NSA[void_vf], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='VoidFinder (Dynesty)')

# %% [markdown]
# ## 2-parent model

# %%
# 1 = wall, 2 = void

ur_fit_bounds2 = [[100, 5000],  # a1 ........ Gaussian A1 amplitude
                  [0, 2],     # mu_a1 ..... Gaussian A1 location
                  [0.01, 3],    # sigma_a1 .. Gaussian A1 scale
                  [0, 20],     # skew_a1 ... Gaussian A1 skew
                  [500, 10000], # b1 ........ Gaussian B1 amplitude
                  [2, 3.5],   # mu_b1 ..... Gaussian B1 location
                  [0.01, 3],     # sigma_b1 .. Gaussian B1 scale
                  [-5, 0],    # skew_b1 ... Gaussian B1 skew
                  [500, 10000], # a2 ........ Gaussian A2 amplitude
                  [0, 2],     # mu_a2 ..... Gaussian A2 location
                  [0.01, 3],     # sigma_a2 .. Gaussian A2 scale
                  [0, 5],       # skew_a2 ... Gaussian A2 skew
                  [500, 10000], # b2 ........ Gaussian B2 amplitude
                  [2, 3.5],   # mu_b2 ..... Gaussian B2 location
                  [0.01, 3],     # sigma_b2 .. Gaussian B2 scale
                  [-5, 0]]      # skew_b2 ... Gaussian B2 skew

V2_ur_bestfit2 = Model_2_fit(ur_fit_bounds2, 
                             ur_NSA[wall_v2], 
                             ur_NSA[void_v2], 
                             ur_bins, 
                             2)

V2_ur_bestfit2
# Out:
# running minimizer...this might take a few minutes...
#       fun: 1782.2994063061421
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.86564347, -0.81747658,  0.0989985 ,  0.98684723, -0.03026376,
#         2.02296634, -1.51696895, -0.15127171, -0.49049654, -0.1672106 ,
#        -1.88724697, -1.48556865,  0.11700773,  1.86848866, -4.38383268,
#        -0.23901521])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 10353
#       nit: 514
#      njev: 609
#    status: 0
#   success: True
#         x: array([ 2.99263868e+03,  1.29979430e+00,  7.94672321e-01,  2.50095454e+00,
#         1.95443895e+03,  2.86740152e+00,  4.45669174e-01, -2.71648342e+00,
#         8.24765269e+03,  1.34885395e+00,  7.47552127e-01,  2.20594153e+00,
#         3.80476000e+03,  2.79006973e+00,  2.96887714e-01, -1.34843588e+00])

# %%
Model_2_plot(V2_ur_bestfit2.x, 
             ur_NSA[wall_v2], 
             ur_NSA[void_v2], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='$V^2$')

# %%
# 1 = wall, 2 = void

ur_fit_bounds2 = [[500, 10000], # a1 ........ Gaussian A1 amplitude
                  [0, 2.1],     # mu_a1 ..... Gaussian A1 location
                  [0.001, 3],   # sigma_a1 .. Gaussian A1 scale
                  [0, 10],      # skew_a1 ... Gaussian A1 skew
                  [100, 10000], # b1 ........ Gaussian B1 amplitude
                  [2.1, 3.5],   # mu_b1 ..... Gaussian B1 location
                  [0.001, 3],   # sigma_b1 .. Gaussian B1 scale
                  [-5, 5],      # skew_b1 ... Gaussian B1 skew
                  [500, 10000], # a2 ........ Gaussian A2 amplitude
                  [1, 2.1],     # mu_a2 ..... Gaussian A2 location
                  [0.001, 3],   # sigma_a2 .. Gaussian A2 scale
                  [0, 5],       # skew_a2 ... Gaussian A2 skew
                  [100, 10000],  # b2 ........ Gaussian B2 amplitude
                  [2.1, 3.5],   # mu_b2 ..... Gaussian B2 location
                  [0.001, 3],   # sigma_b2 .. Gaussian B2 scale
                  [-5, 5]]      # skew_b2 ... Gaussian B2 skew

VF_ur_bestfit2 = Model_2_fit(ur_fit_bounds2, 
                             ur_NSA[wall_vf], 
                             ur_NSA[void_vf], 
                             ur_bins, 
                             2)

VF_ur_bestfit2
# Out:
# running minimizer...this might take a few minutes...
#       fun: 2242.1516636728593
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([ 0.65937614,  0.60708772,  0.75183379,  0.57434591, -0.50177353,
#         0.54665179,  1.84163582,  1.12599991, -0.10468395, -0.18280844,
#        -0.2867182 ,  0.09290488, -0.05861755,  0.02273737, -0.40736267,
#        -0.18890205])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 10931
#       nit: 558
#      njev: 643
#    status: 0
#   success: True
#         x: array([ 9.47512330e+03,  1.50680591e+00,  7.27564328e-01,  1.64179009e+00,
#         2.85092506e+03,  2.57028705e+00,  1.91740850e-01,  6.53311456e-01,
#         1.37352371e+03,  1.54094840e+00,  2.66533754e-01,  3.56517882e-02,
#         2.91162029e+03,  2.78277405e+00,  8.25588282e-01, -2.60771292e+00])

# %%
Model_2_plot(VF_ur_bestfit2.x, 
             ur_NSA[wall_vf], 
             ur_NSA[void_vf], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='VoidFinder')

# %% [markdown]
# ### Nested sampling of Likelihood and Priors

# %% [markdown]
# #### V$^2$

# %%
def prior_xform2_bi_V2(u):
    '''
    Priors for the 16 parameters of bimodal M2.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    a1 = jeffreys(500, 10000, u[0])
    mu_a1 = uniform(1, 2.1, u[1])
    sigma_a1 = uniform(0.01, 2, u[2])
    skew_a1 = uniform(-5, 5, u[3])

    b1 = jeffreys(100, 5000, u[4])
    mu_b1 = uniform(2.1, 3.5, u[5])
    sigma_b1 = uniform(0.01, 2, u[6])
    skew_b1 = uniform(-5, 5, u[7])
    
    a2 = jeffreys(1000, 20000, u[8])
    mu_a2 = uniform(1, 2.1, u[9])
    sigma_a2 = uniform(0.01, 2, u[10])
    skew_a2 = uniform(0, 5, u[11])

    b2 = jeffreys(500, 10000, u[12])
    mu_b2 = uniform(2.1, 3.5, u[13])
    sigma_b2 = uniform(0.01, 2, u[14])
    skew_b2 = uniform(-5, 0, u[15])

    return a1, mu_a1, sigma_a1, skew_a1, b1, mu_b1, sigma_b1, skew_b1, \
           a2, mu_a2, sigma_a2, skew_a2, b2, mu_b2, sigma_b2, skew_b2

# %%
Model_2_sampler(prior_xform2_bi_V2, 
                ur_NSA[wall_v2], 
                ur_NSA[void_v2], 
                ur_bins, 
                2, 
                '_ur_V2')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 11342it [03:27, 54.99it/s, batch: 0 | bound: 139 | nc: 25 | ncall: 259177 | eff(%):  4.368 | loglstar:   -inf < -6752.597 <    inf | logz: -6781.799 +/-  0.337 | dlogz: 2660.879 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12820it [03:59, 54.96it/s, batch: 0 | bound: 162 | nc: 25 | ncall: 300389 | eff(%):  4.261 | loglstar:   -inf < -5086.844 <    inf | logz: -5118.333 +/-  0.349 | dlogz: 2265.504 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16034it [05:05, 56.23it/s, batch: 0 | bound: 206 | nc: 25 | ncall: 384690 | eff(%):  4.163 | loglstar:   -inf < -2897.234 <    inf | logz: -2934.001 +/-  0.379 | dlogz: 1180.405 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16553it [05:21, 54.70it/s, batch: 0 | bound: 214 | nc: 25 | ncall: 407842 | eff(%):  4.054 | loglstar:   -inf < -2693.342 <    inf | logz: -2731.519 +/-  0.387 | dlogz: 977.043 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17301it [05:41, 57.01it/s, batch: 0 | bound: 225 | nc: 25 | ncall: 434100 | eff(%):  3.981 | loglstar:   -inf < -2417.278 <    inf | logz: -2457.398 +/-  0.395 | dlogz: 780.768 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 21710it [07:14, 55.08it/s, batch: 0 | bound: 285 | nc: 25 | ncall: 554532 | eff(%):  3.911 | loglstar:   -inf < -1553.294 <    inf | logz: -1600.772 +/-  0.430 | dlogz: 244.938 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 23788it [08:09, 55.31it/s, batch: 0 | bound: 314 | nc: 25 | ncall: 629029 | eff(%):  3.779 | loglstar:   -inf < -1383.449 <    inf | logz: -1434.191 +/-  0.446 | dlogz: 125.375 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 24682it [08:38, 53.79it/s, batch: 0 | bound: 327 | nc: 25 | ncall: 668670 | eff(%):  3.688 | loglstar:   -inf < -1333.600 <    inf | logz: -1385.981 +/-  0.453 | dlogz: 108.412 >  0.010]   /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 53343it [23:28, 37.87it/s, batch: 6 | bound: 674 | nc: 25 | ncall: 1405342 | eff(%):  3.796 | loglstar: -1172.072 < -1161.321 < -1164.405 | logz: -1236.883 +/-  0.522 | stop:  0.865]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model2_ur_V2'

# %%
temp_infile = open('dynesty_output/sampler_results_model2_ur_V2.pickle', 'rb')
dres2_V2_ur = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.cornerplot(dres2_V2_ur, smooth=0.03, 
                              labels=labels2_bi, 
                              truths=V2_ur_bestfit2.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.traceplot(dres2_V2_ur, 
                             labels=labels2_bi, 
                             truths=V2_ur_bestfit2.x,
                             fig=plt.subplots(n_params, 2, figsize=(0.5*n_params, 2.6*n_params)), 
                             thin=10)

fig.tight_layout();

# %%
lnzM2_V2_ur = dres2_V2_ur.logz[-1]
lnzM2_V2_ur
# Out:
# -1236.864949723582

# %%
V2_ur_bestfit2_dynesty,_ = dyfunc.mean_and_cov(dres2_V2_ur.samples, 
                                               np.exp(dres2_V2_ur.logwt - lnzM2_V2_ur))

V2_ur_bestfit2_dynesty
# Out:
# array([ 3.68597803e+03,  1.40871329e+00,  7.55199369e-01,  1.95738665e+00,
#         1.39506856e+03,  2.64010666e+00,  2.05260318e-01, -5.40654204e-03,
#         8.90703670e+03,  1.38112831e+00,  7.47501489e-01,  2.06634328e+00,
#         3.32860162e+03,  2.72777985e+00,  2.27578066e-01, -6.98066746e-01])

# %%
Model_2_plot(V2_ur_bestfit2.x, 
             ur_NSA[wall_v2], 
             ur_NSA[void_v2], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='$V^2$ (minimize)')

Model_2_plot(V2_ur_bestfit2_dynesty, 
             ur_NSA[wall_v2], 
             ur_NSA[void_v2], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='$V^2$ (Dynesty)')

# %% [markdown]
# #### VoidFinder

# %%
def prior_xform2_bi_VF(u):
    '''
    Priors for the 16 parameters of bimodal M2.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    a1 = jeffreys(1000, 10000, u[0])
    mu_a1 = uniform(1, 2.1, u[1])
    sigma_a1 = uniform(0.01, 2, u[2])
    skew_a1 = uniform(0, 5, u[3])

    b1 = jeffreys(500, 10000, u[4])
    mu_b1 = uniform(2.1, 3.5, u[5])
    sigma_b1 = uniform(0.01, 2, u[6])
    skew_b1 = uniform(-5, 0, u[7])
    
    a2 = jeffreys(500, 10000, u[8])
    mu_a2 = uniform(1, 2.1, u[9])
    sigma_a2 = uniform(0.01, 2, u[10])
    skew_a2 = uniform(0, 5, u[11])

    b2 = jeffreys(100, 5000, u[12])
    mu_b2 = uniform(2.1, 3.5, u[13])
    sigma_b2 = uniform(0.01, 2, u[14])
    skew_b2 = uniform(-5, 5, u[15])

    return a1, mu_a1, sigma_a1, skew_a1, b1, mu_b1, sigma_b1, skew_b1, \
           a2, mu_a2, sigma_a2, skew_a2, b2, mu_b2, sigma_b2, skew_b2

# %%
Model_2_sampler(prior_xform2_bi_VF, 
                ur_NSA[wall_vf], 
                ur_NSA[void_vf], 
                ur_bins, 
                2, 
                '_ur_VoidFinder')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 12230it [03:24, 56.75it/s, batch: 0 | bound: 156 | nc: 25 | ncall: 282488 | eff(%):  4.322 | loglstar:   -inf < -5009.675 <    inf | logz: -5040.893 +/-  0.351 | dlogz: 2073.206 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13188it [03:48, 60.16it/s, batch: 0 | bound: 177 | nc: 25 | ncall: 317586 | eff(%):  4.146 | loglstar:   -inf < -4223.639 <    inf | logz: -4255.334 +/-  0.352 | dlogz: 1586.637 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13544it [03:55, 60.21it/s, batch: 0 | bound: 183 | nc: 25 | ncall: 328521 | eff(%):  4.116 | loglstar:   -inf < -3983.052 <    inf | logz: -4015.887 +/-  0.357 | dlogz: 1378.199 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13754it [04:00, 61.43it/s, batch: 0 | bound: 187 | nc: 25 | ncall: 336247 | eff(%):  4.084 | loglstar:   -inf < -3852.399 <    inf | logz: -3885.449 +/-  0.359 | dlogz: 1391.790 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13785it [04:04, 17.36it/s, batch: 0 | bound: 189 | nc: 25 | ncall: 342304 | eff(%):  4.021 | loglstar:   -inf < -3835.069 <    inf | logz: -3867.042 +/-  0.354 | dlogz: 1372.929 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14151it [04:12, 60.59it/s, batch: 0 | bound: 195 | nc: 25 | ncall: 353372 | eff(%):  3.999 | loglstar:   -inf < -3580.443 <    inf | logz: -3614.954 +/-  0.367 | dlogz: 1120.916 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14265it [04:18, 56.12it/s, batch: 0 | bound: 198 | nc: 25 | ncall: 362823 | eff(%):  3.926 | loglstar:   -inf < -3509.510 <    inf | logz: -3542.986 +/-  0.363 | dlogz: 1350.434 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14291it [04:22, 14.55it/s, batch: 0 | bound: 200 | nc: 25 | ncall: 368112 | eff(%):  3.877 | loglstar:   -inf < -3496.031 <    inf | logz: -3530.028 +/-  0.364 | dlogz: 1337.702 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14481it [04:28, 58.88it/s, batch: 0 | bound: 204 | nc: 25 | ncall: 376715 | eff(%):  3.839 | loglstar:   -inf < -3392.965 <    inf | logz: -3428.118 +/-  0.367 | dlogz: 1235.666 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14813it [04:39, 55.42it/s, batch: 0 | bound: 210 | nc: 25 | ncall: 388249 | eff(%):  3.810 | loglstar:   -inf < -3217.706 <    inf | logz: -3252.935 +/-  0.371 | dlogz: 1117.271 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15456it [04:53, 56.95it/s, batch: 0 | bound: 220 | nc: 25 | ncall: 407638 | eff(%):  3.787 | loglstar:   -inf < -2900.131 <    inf | logz: -2935.957 +/-  0.374 | dlogz: 939.655 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15897it [05:05, 56.57it/s, batch: 0 | bound: 227 | nc: 25 | ncall: 423256 | eff(%):  3.751 | loglstar:   -inf < -2716.425 <    inf | logz: -2752.423 +/-  0.376 | dlogz: 834.539 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16013it [05:10, 56.72it/s, batch: 0 | bound: 230 | nc: 25 | ncall: 430026 | eff(%):  3.719 | loglstar:   -inf < -2676.390 <    inf | logz: -2713.445 +/-  0.381 | dlogz: 795.556 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16954it [05:30, 58.61it/s, batch: 0 | bound: 244 | nc: 25 | ncall: 458879 | eff(%):  3.691 | loglstar:   -inf < -2352.142 <    inf | logz: -2391.129 +/-  0.388 | dlogz: 622.473 >  0.010]  /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 17543it [05:45, 60.18it/s, batch: 0 | bound: 253 | nc: 25 | ncall: 481410 | eff(%):  3.640 | loglstar:   -inf < -2189.472 <    inf | logz: -2229.242 +/-  0.395 | dlogz: 674.697 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17750it [05:53, 59.65it/s, batch: 0 | bound: 257 | nc: 25 | ncall: 494129 | eff(%):  3.589 | loglstar:   -inf < -2136.131 <    inf | logz: -2176.478 +/-  0.398 | dlogz: 621.568 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17962it [06:03, 57.45it/s, batch: 0 | bound: 261 | nc: 25 | ncall: 509080 | eff(%):  3.525 | loglstar:   -inf < -2082.587 <    inf | logz: -2123.525 +/-  0.401 | dlogz: 568.267 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 18011it [06:11, 23.43it/s, batch: 0 | bound: 263 | nc: 25 | ncall: 520965 | eff(%):  3.454 | loglstar:   -inf < -2071.278 <    inf | logz: -2111.999 +/-  0.398 | dlogz: 556.487 >  0.010]   /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18625it [06:26, 52.88it/s, batch: 0 | bound: 273 | nc: 25 | ncall: 542876 | eff(%):  3.428 | loglstar:   -inf < -1934.570 <    inf | logz: -1976.113 +/-  0.403 | dlogz: 469.875 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18902it [06:37, 59.27it/s, batch: 0 | bound: 278 | nc: 25 | ncall: 558800 | eff(%):  3.380 | loglstar:   -inf < -1880.394 <    inf | logz: -1922.728 +/-  0.408 | dlogz: 415.999 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 19146it [06:48, 54.54it/s, batch: 0 | bound: 283 | nc: 25 | ncall: 576306 | eff(%):  3.319 | loglstar:   -inf < -1837.467 <    inf | logz: -1880.598 +/-  0.409 | dlogz: 388.460 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21302it [07:35, 61.02it/s, batch: 0 | bound: 313 | nc: 25 | ncall: 644077 | eff(%):  3.305 | loglstar:   -inf < -1544.075 <    inf | logz: -1590.412 +/-  0.426 | dlogz: 235.438 >  0.010]   /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21585it [07:46, 53.68it/s, batch: 0 | bound: 318 | nc: 25 | ncall: 661304 | eff(%):  3.262 | loglstar:   -inf < -1514.971 <    inf | logz: -1561.678 +/-  0.428 | dlogz: 206.121 >  0.010]/Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 33929it [11:35, 55.91it/s, batch: 0 | bound: 484 | nc: 25 | ncall: 984710 | eff(%):  3.444 | loglstar:   -inf < -1175.693 <    inf | logz: -1243.410 +/-  0.514 | dlogz:  7.618 >  0.010] /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:221: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /Users/kellydouglass/opt/anaconda3/lib/python3.8/site-packages/dynesty/sampling.py:243: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 52579it [22:24, 39.10it/s, batch: 6 | bound: 696 | nc: 25 | ncall: 1485372 | eff(%):  3.540 | loglstar: -1176.177 < -1166.584 < -1169.698 | logz: -1240.455 +/-  0.520 | stop:  0.912]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model2_ur_VoidFinder'

# %%
temp_infile = open('dynesty_output/sampler_results_model2_ur_VoidFinder.pickle', 'rb')
dres2_VF_ur = pickle.load(temp_infile)
temp_infile.close()

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.cornerplot(dres2_VF_ur, smooth=0.03, 
                              labels=labels2_bi, 
                              truths=VF_ur_bestfit2.x,
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')

# %%
lnzM2_VF_ur = dres2_VF_ur.logz[-1]
lnzM2_VF_ur
# Out:
# -1240.4597709626619

# %%
VF_ur_bestfit2_dynesty,_ = dyfunc.mean_and_cov(dres2_VF_ur.samples, 
                                               np.exp(dres2_VF_ur.logwt - lnzM2_VF_ur))

VF_ur_bestfit2_dynesty
# Out:
# array([ 8.42304840e+03,  1.42625480e+00,  7.44721673e-01,  1.99088888e+00,
#         3.65725346e+03,  2.74335004e+00,  2.30875725e-01, -7.84145199e-01,
#         3.50882866e+03,  1.30871050e+00,  7.29916878e-01,  2.13933530e+00,
#         7.78138019e+02,  2.55216711e+00,  2.11541579e-01,  4.10173946e-01])

# %%
Model_2_plot(VF_ur_bestfit2.x, 
             ur_NSA[wall_vf], 
             ur_NSA[void_vf], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='VoidFinder (minimize)')

Model_2_plot(VF_ur_bestfit2_dynesty, 
             ur_NSA[wall_vf], 
             ur_NSA[void_vf], 
             ur_bins, 
             2, 
             xlabel_text='u - r', 
             title_text='VoidFinder (Dynesty)')

# %% [markdown]
# ## Bayes Factor

# %%
lnB12_V2_ur = lnzM1_V2_ur - lnzM2_V2_ur

B12_V2_ur = np.exp(lnB12_V2_ur)

print('V2 (u - r): B12 = {:.3g}; log(B12) = {:.3g}'.format(B12_V2_ur, np.log10(B12_V2_ur)))
# Out:
# V2 (u - r): B12 = 1.6e-29; log(B12) = -28.8

# %%
lnB12_VF_ur = lnzM1_VF_ur - lnzM2_VF_ur

B12_VF_ur = np.exp(lnB12_VF_ur)

print('VoidFinder (u - r): B12 = {:.3g}; log(B12) = {:.3f}'.format(B12_VF_ur, lnB12_VF_ur*np.log10(np.exp(1))))
# Out:
# VoidFinder (u - r): B12 = 0; log(B12) = -1555.761

# %% [markdown]
# So both VoidFinder and V$^2$ favor $\mathcal{M}_2$, in which the two data sets come from different parent distributions, although VoidFinder favors it much more than V$^2$.
