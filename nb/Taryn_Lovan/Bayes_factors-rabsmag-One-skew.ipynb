# %% [markdown]
# Calculate the Bayes Factor for the absolute magnitude to determine whether the void and wall samples are drawn from the same or different parent distributions.

# %%
from astropy.table import Table
from astropy.io import fits

import numpy as np

import sys

import pickle

import dynesty
from dynesty import plotting as dyplot
from dynesty import utils as dyfunc

import matplotlib
import matplotlib.pyplot as plt

# sys.path.insert(1,"/home/codebind/Bootes/Void_analysis/nb/Fatima_Zaidouni/")
from functions import Model_1_plot, Model_2_plot, uniform, jeffreys, Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler
#from functions_gauss import Model_1_fit, Model_2_fit, Model_1_sampler, Model_2_sampler

np.set_printoptions(threshold=sys.maxsize)

# %%
matplotlib.rc('font', size=14)
matplotlib.rc('font', family='DejaVu Sans')

# %% [markdown]
# # Data
# ## Full NSA Catalog

# %%
data_filename = '/home/codebind/Bootes/NSA_Full.fits'

hdu = fits.open(data_filename)
data = Table(hdu[1].data)
hdu.close()

# %% [markdown]
# ### Just keep the main SDSS DR7 footprint

# %%
# When the catalog is the NSA, only keep those objects which were originally in the DR7 LSS
catalog_SDSS = data[data['IN_DR7_LSS'] == 1]
del data

ra_boolean = np.logical_and(catalog_SDSS['RA'] > 110, catalog_SDSS['RA'] < 270)
catalog_north = catalog_SDSS[ra_boolean]
del catalog_SDSS

strip_boolean = np.logical_and.reduce([catalog_north['RA'] > 250, 
                                       catalog_north['RA'] < 269, 
                                       catalog_north['DEC'] > 51, 
                                       catalog_north['DEC'] < 67])
catalog_main = catalog_north[~strip_boolean]
del catalog_north

# %%
rabsmag_NSA = np.array(catalog_main['ELPETRO_ABSMAG'][:,4])

# %%
del catalog_main

# %% [markdown]
# ## Kirshner Data

# %%
KNSA = Table.read('/home/codebind/Bootes/My Code/KNSA.txt', format = "ascii.commented_header")

# %% [markdown]
# # Fit the $M_r$ distributions with skewnormal distributions
#
# Both one- and two-parent models

# %%
#rabsmag_bins = np.linspace(-25, -12.5, 170)
rabsmag_bins = np.arange(-24, -15, 0.1)
k_bins = np.arange(-24, -15, 0.4)

# %% [markdown]
# This is a unimodal distribution, but we are fitting it with a sum of two skew normals to account for the extra bumps in the distributions.
#
# ## 1-parent model

# %%
'''
rabsmag_fit_bounds1 = [[0.1, 10],     # s ...... Gaussian 1 to 2 scale factor
                       [1000, 20000], # a ...... Gaussian amplitude
                       [-22, -18],    # mu ..... Gaussian location
                       [0.1, 3],      # sigma .. Gaussian scale
                       [0, 5]]        # skew ... Gaussian skew
'''
rabsmag_fit_bounds1 = [[1e-5, 1],    # s ........ Gaussian 1 to 2 scale factor
                       [1000, 100000],  # a ........ Gaussian a amplitude
                       [-22, -18],      # mu_a ..... Gaussian a location
                       [1e-5, 2],    # sigma_a .. Gaussian a scale
                       [-5, 5]]      # skew_a ... Gaussian a skew

rabsmag_bestfit1 = Model_1_fit(rabsmag_fit_bounds1, 
                                  rabsmag_NSA, 
                                  KNSA['ABSMAG'], 
                                  rabsmag_bins, 
                                  k_bins, 
                                  1)

rabsmag_bestfit1
# Out:
# running minimizer...this might take a few minutes...
#       fun: 9846.239313677655
#  hess_inv: <5x5 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.82854967,  0.00545852,  0.61827445, -0.96333679, -1.70821296])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 786
#       nit: 66
#      njev: 131
#    status: 0
#   success: True
#         x: array([ 2.38261176e-03,  5.10536473e+04, -2.14807124e+01,  1.75892140e+00,
#         2.91155586e+00])

# %%
Model_1_plot(rabsmag_bestfit1.x, 
             rabsmag_NSA, 
             KNSA['ABSMAG'], 
             rabsmag_bins, 
             k_bins,
             1, 
             xlabel_text='$M_r$')

# %% [markdown]
# ### Nested sampling of Likelihood and Priors

# %%
def prior_xform1_uni_V2(u):
    '''
    Priors for the 5 parameters of unimodel M1 for V2.  Required by 
    the dynesty sampler.  Note that this is customized for the 
    absolute magnitude fitting.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    '''
    s = uniform(0.1, 5, u[0])
    a = jeffreys(1000, 10000, u[1])
    mu = uniform(-22, -18, u[2])
    sigma = uniform(0.01, 5, u[3])
    skew = uniform(0, 5, u[4])

    return s, a, mu, sigma, skew
    '''
    s = uniform(1e-5, 1e-2, u[0])
    
    a = jeffreys(30000, 40000, u[1])
    mu_a = uniform(-22, -20, u[2])
    sigma_a = uniform(1, 2, u[3])
    skew_a = uniform(2, 3, u[4])
    
    return s, a, mu_a, sigma_a, skew_a

# %%
Model_1_sampler(prior_xform1_uni_V2, 
                rabsmag_NSA, 
                KNSA['ABSMAG'], 
                rabsmag_bins,
                k_bins,
                1, 
                '_rabsmag')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 5508it [02:40, 34.41it/s, batch: 0 | bound: 18 | nc: 1 | ncall: 62395 | eff(%):  8.688 | loglstar:   -inf < -31733.850 <    inf | logz: -31746.843 +/-  0.113 | dlogz: 17931.567 >  0.010]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 Model_1_sampler(prior_xform1_uni_V2,
#       2                 rabsmag_NSA,
#       3                 KNSA['ABSMAG'],
#       4                 rabsmag_bins,
#       5                 k_bins,
#       6                 2,
#       7                 '_rabsmag')
#
# File ~/Bootes/Void_analysis/nb/Taryn_Lovan/functions.py:815, in Model_1_sampler(prior_, data1, data2, bins1, bins2, peaks, fname_suffix)
#     804 print("running the nested sampler... this might take from minutes to hours...")
#     806 dsampler = dynesty.DynamicNestedSampler(logLjoint1_skew,
#     807                                         prior_,
#     808                                         ndim=1 + 4*peaks,
#    (...)
#     812                                         sample='auto'
#     813                                        )
# --> 815 dsampler.run_nested()
#     816 dres1 = dsampler.results
#     818 with open('dynesty_output/sampler_results_model1'+fname_suffix+'.pickle', 'wb') as dres1_file:
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/dynamicsampler.py:1664, in DynamicSampler.run_nested(self, nlive_init, maxiter_init, maxcall_init, dlogz_init, logl_max_init, n_effective_init, nlive_batch, wt_function, wt_kwargs, maxiter_batch, maxcall_batch, maxiter, maxcall, maxbatch, n_effective, stop_function, stop_kwargs, use_stop, save_bounds, print_progress, print_func, live_points)
#    1662 try:
#    1663     if not self.base:
# -> 1664         for results in self.sample_initial(
#    1665                 nlive=nlive_init,
#    1666                 dlogz=dlogz_init,
#    1667                 maxcall=maxcall_init,
#    1668                 maxiter=maxiter_init,
#    1669                 logl_max=logl_max_init,
#    1670                 live_points=live_points,
#    1671                 n_effective=n_effective_init):
#    1673             ncall += results.nc
#    1674             niter += 1
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/dynamicsampler.py:846, in DynamicSampler.sample_initial(self, nlive, update_interval, first_update, maxiter, maxcall, logl_max, dlogz, n_effective, live_points, save_samples, resume)
#     844 # Run the sampler internally as a generator.
#     845 for i in range(1):
# --> 846     for it, results in enumerate(
#     847             self.sampler.sample(maxiter=maxiter,
#     848                                 save_samples=save_samples,
#     849                                 maxcall=maxcall,
#     850                                 dlogz=dlogz)):
#     851         # Grab results.
#     852
#     853         # Save our base run (which we will use later).
#     854         add_info = dict(id=results.worst,
#     855                         u=results.ustar,
#     856                         v=results.vstar,
#    (...)
#     867                         bounditer=results.bounditer,
#     868                         scale=self.sampler.scale)
#     870         self.base_run.append(add_info)
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:740, in Sampler.sample(self, maxiter, maxcall, dlogz, logl_max, n_effective, add_live, save_bounds, save_samples)
#     735 loglstar_new = self.live_logl[worst]  # new likelihood
#     737 # Sample a new live point from within the likelihood constraint
#     738 # `logl > loglstar` using the bounding distribution and sampling
#     739 # method from our sampler.
# --> 740 u, v, logl, nc = self._new_point(loglstar_new)
#     741 ncall += nc
#     742 self.ncall += nc
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:360, in Sampler._new_point(self, loglstar)
#     357 ncall, nupdate = 0, 0
#     358 while True:
#     359     # Get the next point from the queue
# --> 360     u, v, logl, nc, blob = self._get_point_value(loglstar)
#     361     ncall += nc
#     363     # Bounding checks.
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:343, in Sampler._get_point_value(self, loglstar)
#     341 # If the queue is empty, refill it.
#     342 if self.nqueue <= 0:
# --> 343     self._fill_queue(loglstar)
#     345 # Grab the earliest entry.
#     346 u, v, logl, nc, blob = self.queue.pop(0)
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/sampler.py:311, in Sampler._fill_queue(self, loglstar)
#     308 while self.nqueue < self.queue_size:
#     309     if self._beyond_unit_bound(loglstar):
#     310         # Propose points using the provided sampling/bounding options.
# --> 311         point, axes = self.propose_point(*args)
#     312         evolve_point = self.evolve_point
#     313     else:
#     314         # Propose/evaluate points directly from the unit cube.
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/nestedsamplers.py:602, in MultiEllipsoidSampler.propose_unif(self, *args)
#     600     u, idx = self.mell.sample(rstate=self.rstate)
#     601     # Check if the point is within the unit cube.
# --> 602     if unitcheck(u, nonb):
#     603         break  # if successful, we're done!
#     604 if self.ncdim != self.npdim:
#
# File ~/anaconda3/envs/bootes/lib/python3.8/site-packages/dynesty/utils.py:334, in unitcheck(u, nonbounded)
#     328 """Check whether `u` is inside the unit cube. Given a masked array
#     329 `nonbounded`, also allows periodic boundaries conditions to exceed
#     330 the unit cube."""
#     332 if nonbounded is None:
#     333     # No periodic boundary conditions provided.
# --> 334     return np.min(u) > 0 and np.max(u) < 1
#     335 else:
#     336     # Alternating periodic and non-periodic boundary conditions.
#     337     unb = u[nonbounded]
#
# File <__array_function__ internals>:180, in amin(*args, **kwargs)
#
# File ~/VAST/.eggs/numpy-1.22.4-py3.8-linux-x86_64.egg/numpy/core/fromnumeric.py:2916, in amin(a, axis, out, keepdims, initial, where)
#    2800 @array_function_dispatch(_amin_dispatcher)
#    2801 def amin(a, axis=None, out=None, keepdims=np._NoValue, initial=np._NoValue,
#    2802          where=np._NoValue):
#    2803     """
#    2804     Return the minimum of an array or minimum along an axis.
#    2805
#    (...)
#    2914     6
#    2915     """
# -> 2916     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#    2917                           keepdims=keepdims, initial=initial, where=where)
#
# File ~/VAST/.eggs/numpy-1.22.4-py3.8-linux-x86_64.egg/numpy/core/fromnumeric.py:70, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#      73     if type(obj) is not mu.ndarray:
#      74         try:
#
# KeyboardInterrupt:

# %%
#temp_infile = open('dynesty_output/sampler_results_model1_gauss_rabsmag_V2.pickle', 'rb')
temp_infile = open('dynesty_output/sampler_results_model1_rabsmag.pickle', 'rb')
dres1_rabsmag = pickle.load(temp_infile)
temp_infile.close()

# %%
labels1_uni = ['s', 'a', r'$\mu$', r'$\sigma$', 'skew']
labels2_uni = ['a', r'$\mu_a$', r'$\sigma_a$', 'skew$_a$', 'b', r'$\mu_b$', r'$\sigma_b$', 'skew$_b$']

# %%
labels1_bi = ['s', 'a', r'$\mu_a$', r'$\sigma_a$', 'skew$_a$', 
                    'b', r'$\mu_b$', r'$\sigma_b$', 'skew$_b$']
labels2_bi = ['$a_1$', r'$\mu_{1a}$', r'$\sigma_{1a}$', 'skew$_{1a}$', 
               '$b_1$', r'$\mu_{1b}$', r'$\sigma_{1b}$', 'skew$_{1b}$', 
               '$a_2$', r'$\mu_{2a}$', r'$\sigma_{2a}$', 'skew$_{2a}$', 
               '$b_2$', r'$\mu_{2b}$', r'$\sigma_{2b}$', 'skew$_{2b}$']

# %%
#n_params = len(labels1_uni)
n_params = len(labels1_bi)

fig, axes = dyplot.cornerplot(dres1_rabsmag, smooth=0.03, 
                              labels=labels1_bi, 
                              #labels=labels1_uni, 
                              show_titles=True, 
                              truths=rabsmag_bestfit1.x, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)), 
                              color='#1f77d4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       1 #n_params = len(labels1_uni)
#       2 n_params = len(labels1_bi)
#       4 fig, axes = dyplot.cornerplot(dres1_rabsmag, smooth=0.03,
#       5                               labels=labels1_bi,
#       6                               #labels=labels1_uni,
#       7                               show_titles=True,
# ----> 8                               truths=rabsmag_bestfit1.x,
#       9                               quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]],
#      10                               quantiles=[0.16, 0.5, 0.84],
#      11                               fig=plt.subplots(n_params, n_params, figsize=(2.5*n_params, 2.6*n_params)),
#      12                               color='#1f77d4')
#
# NameError: name 'rabsmag_bestfit1' is not defined

# %%
lnzM1_rabsmag = dres1_rabsmag.logz[-1]
lnzM1_rabsmag
# Out:
# -984.9842441026252

# %%
rabsmag_bestfit1_dynesty,_ = dyfunc.mean_and_cov(dres1_rabsmag.samples, 
                                                    np.exp(dres1_rabsmag.logwt - lnzM1_rabsmag))

rabsmag_bestfit1_dynesty
# Out:
# array([ 2.39243320e-03,  3.27003589e+04, -2.13145073e+01,  1.16096111e+00,
#         2.37682003e+00,  1.84617747e+04, -2.12272584e+01,  2.24290898e+00,
#         1.94569114e+00])

# %%
Model_1_plot(rabsmag_bestfit1.x, 
             rabsmag_NSA, 
             KNSA['ABSMAG'], 
             rabsmag_bins,
             k_bins,
             1, 
             xlabel_text='$M_r$', 
             title_text='$V^2$ (minimize)')

Model_1_plot(rabsmag_bestfit1_dynesty, 
             rabsmag_NSA, 
             KNSA['ABSMAG'], 
             rabsmag_bins,
             k_bins,
             1, 
             xlabel_text='$M_r$', 
             title_text='$V^2$ (Dynesty)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 Model_1_plot(rabsmag_bestfit1.x,
#       2              rabsmag_NSA,
#       3              KNSA['ABSMAG'],
#       4              rabsmag_bins,
#       5              k_bins,
#       6              2,
#       7              xlabel_text='$M_r$',
#       8              title_text='$V^2$ (minimize)')
#      10 Model_1_plot(rabsmag_bestfit1_dynesty,
#      11              rabsmag_NSA,
#      12              KNSA['ABSMAG'],
#    (...)
#      16              xlabel_text='$M_r$',
#      17              title_text='$V^2$ (Dynesty)')
#
# NameError: name 'rabsmag_bestfit1' is not defined

# %% [markdown]
# ## 2-parent model

# %%
rabsmag_fit_bounds2 = [[10000, 100000], # a1 ........ Gaussian A amplitude
                       [-22, -21.2],    # mu_a1 ..... Gaussian A location
                       [1, 10],     # sigma_a1 .. Gaussian A scale
                       [0, 10],       # skew_a1 ... Gaussian A skew
                       [1, 200], # a2 ........ Gaussian A amplitude
                       [-23, -21],    # mu_a2 ..... Gaussian A location
                       [0.1, 5],      # sigma_a2 .. Gaussian A scale
                       [-5, 5],       # skew_a2 ... Gaussian A skew

rabsmag_bestfit2 = Model_2_fit(rabsmag_fit_bounds2, 
                                  rabsmag_NSA, 
                                  KNSA['ABSMAG'], 
                                  rabsmag_bins,
                               k_bins,
                                  1)

rabsmag_bestfit2
# Out:
# running minimizer...this might take a few minutes...
#       fun: 1408.7420872586147
#  hess_inv: <16x16 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-0.02114405, -0.8760707 , -0.0338332 , -0.09356426,  0.02075755,
#        -0.3219611 , -1.06942934, -0.29890543,  0.11423261,  0.71231619,
#         0.44858553, -0.40702162,  0.0522959 , -0.9091763 , -0.3663217 ,
#         0.28310294])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 12495
#       nit: 631
#      njev: 735
#    status: 0
#   success: True
#         x: array([ 2.52376459e+04, -2.13632022e+01,  2.13922950e+00,  8.03189588e+00,
#         2.58561171e+04, -2.01725290e+01,  9.52254237e-01, -8.08260485e-01,
#         1.17704395e+02, -2.14603553e+01,  1.37328985e+00,  1.43065796e+00,
#         1.34229492e+02, -1.80000000e+01,  2.65491791e+01,  9.68853376e+00])

# %%
Model_2_plot(rabsmag_bestfit2.x, 
             rabsmag_NSA, 
             KNSA['ABSMAG'], 
             rabsmag_bins,
             k_bins,
             1, 
             xlabel_text='$M_r$', 
             title_text='$V^2$')

# %% [markdown]
# #### Nested sampling of Likelihood and Priors

# %%
# def prior_xform2_uni_V2(u):
#     '''
#     Priors for the 8 parameters of unimodel M2.  Required by the dynesty 
#     sampler.


#     PARAMETERS
#     ==========

#     u : ndarray
#         Array of uniform random numbers between 0 and 1.


#     RETURNS
#     =======
    
#     priors : ndarray
#         Transformed random numbers giving prior ranges on model parameters.
#     '''

#     a = jeffreys(1000, 10000, u[0])
#     mu_a = uniform(-24, -18, u[1])
#     sigma_a = uniform(0.1, 5, u[2])
#     skew_a = uniform(0, 5, u[3])

#     b = jeffreys(10000, 50000, u[4])
#     mu_b = uniform(-24, -18, u[5])
#     sigma_b = uniform(0.1, 5, u[6])
#     skew_b = uniform(0, 5, u[7])

#     return a, mu_a, sigma_a, skew_a, b, mu_b, sigma_b, skew_b

# %%
def prior_xform2_bi_V2(u):
    '''
    Priors for the 16 parameters of bimodel M2.  Required by the dynesty 
    sampler.


    PARAMETERS
    ==========

    u : ndarray
        Array of uniform random numbers between 0 and 1.


    RETURNS
    =======
    
    priors : ndarray
        Transformed random numbers giving prior ranges on model parameters.
    '''

    a1 = jeffreys(30000, 50000, u[0])
    mu_a1 = uniform(-23, -21.2, u[1])
    sigma_a1 = uniform(.01, 5, u[2])
    skew_a1 = uniform(-10, 10, u[3])
    
    a2 = jeffreys(10, 150, u[8])
    mu_a2 = uniform(-23, -21, u[9])
    sigma_a2 = uniform(0.01, 10, u[10])
    skew_a2 = uniform(-10, 10, u[11])

    return a1, mu_a1, sigma_a1, skew_a1, b1, \
           a2, mu_a2, sigma_a2, skew_a2

# %%
Model_2_sampler(prior_xform2_bi_V2, 
                rabsmag_NSA, 
                KNSA['ABSMAG'], 
                rabsmag_bins,
                k_bins,
                1, 
                '_rabsmag')
# Out:
# running the nested sampler... this might take from minutes to hours...
# 67179it [20:38, 54.26it/s, batch: 0 | bound: 419 | nc: 1 | ncall: 2288135 | eff(%):  2.936 | loglstar:   -inf < -951.274 <    inf | logz: -1012.818 +/-  0.231 | dlogz:  0.000 >  0.010]
# sampler output saved as pickle file 'dynesty_output/sampler_results_model2_rabsmag'

# %%
temp_infile = open('dynesty_output/sampler_results_model2_rabsmag.pickle', 'rb')
dres2_rabsmag = pickle.load(temp_infile)
temp_infile.close()

# %%
nparams = len(labels2_bi)

fig, axes = dyplot.cornerplot(dres2_rabsmag, smooth=0.03, 
                              labels=labels2_bi, 
                              truths=rabsmag_bestfit2.x, 
                              show_titles=True, 
                              quantiles_2d=[1-np.exp(-0.5*r**2) for r in [1, 2, 3]], 
                              quantiles=[0.16, 0.5, 0.84], 
                              fig=plt.subplots(nparams, nparams, figsize=(2.5*nparams, 2.6*nparams)), 
                              color='#1f77d4')

# %%
n_params = len(labels2_bi)

fig, axes = dyplot.traceplot(dres2_rabsmag, 
                             labels=labels2_bi, 
                             truths=rabsmag_bestfit2.x, 
                             fig=plt.subplots(n_params, 1, figsize=(8, 2.6*n_params)), 
                             thin=10)

fig.tight_layout();

# %%
lnzM2_rabsmag = dres2_rabsmag.logz[-1]
lnzM2_rabsmag
# Out:
# -995.19074814312

# %%
rabsmag_bestfit2_dynesty,_ = dyfunc.mean_and_cov(dres2_rabsmag.samples, 
                                                    np.exp(dres2_rabsmag.logwt - lnzM2_rabsmag))

rabsmag_bestfit2_dynesty
# Out:
# array([ 3.12024604e+04, -2.13110826e+01,  1.27680308e+00,  2.34706965e+00,
#         1.99509898e+04, -2.12420190e+01,  2.12896295e+00,  2.00675479e+00,
#         1.10065119e+02, -2.04147080e+01,  1.12453694e+00, -3.68848543e-01,
#         1.28129885e+01, -1.88708709e+01,  2.83815292e+00,  8.19570416e+00])

# %%
Model_2_plot(rabsmag_bestfit2.x, 
             rabsmag_NSA, 
             KNSA['ABSMAG'], 
             rabsmag_bins, 
             k_bins,
             1, 
             xlabel_text='$M_r$', 
             title_text='$V^2$ (minimize)')

Model_2_plot(rabsmag_bestfit2_dynesty, 
             rabsmag_NSA, 
             KNSA["ABSMAG"], 
             rabsmag_bins, 
             k_bins,
             1, 
             xlabel_text='$M_r$', 
             title_text='$V^2$ (Dynesty)')

# %% [markdown]
# ## Bayes Factor

# %%
lnB12_rabsmag = lnzM1_rabsmag - lnzM2_rabsmag

B12_rabsmag = np.exp(lnB12_rabsmag)

#print('V2 Mr: B12 = {:.3g}; log(B12) = {:.3g}'.format(B12_V2_rabsmag, np.log10(B12_V2_rabsmag)))
print('Mr: B12 = {:.3g}; log(B12) = {:.3f}'.format(B12_rabsmag, lnB12_rabsmag*np.log10(np.exp(1))))
# Out:
# Mr: B12 = 2.71e+04; log(B12) = 4.433

# %% [markdown]
# So both $V^2$ and VoidFinder overwhelmingly favor model $\mathcal{M}_2$, in which the two data sets come from different parent distributions.
